# %%
import pandas as pd
import numpy as np
from numpy.random import randn
# %matplotlib inline

# %%
df1 = pd.DataFrame(np.random.rand(5,5),['01','02','03','04','05'],['A','B','C','D','E'])
df2 = pd.DataFrame(np.random.rand(9,5),['1','2','3','4','5','6','7','8','9'],['a','b','c','d','e'])

# %%
df1
# Out:
#            A         B         C         D         E
# 01  0.005990  0.748313  0.879295  0.583680  0.597081
# 02  0.628347  0.170815  0.787995  0.206091  0.385820
# 03  0.666180  0.702781  0.761718  0.268508  0.075438
# 04  0.042761  0.864745  0.148027  0.937365  0.770212
# 05  0.675730  0.564742  0.437562  0.018736  0.912058

# %%
df1['A'].hist()
# Out:
# <AxesSubplot:>

# %%
import matplotlib.pyplot as plt
plt.style.use('ggplot')

# %%
df1['A'].hist()
# Out:
# <AxesSubplot:>

# %%
plt.style.use('dark_background')
df1['A'].hist()
# Out:
# <AxesSubplot:>

# %%
plt.style.use('ggplot')

# %%
df2.plot.area()
# Out:
# <AxesSubplot:>

# %%
df2.head()
# Out:
#           a         b         c         d         e
# 1  0.811854  0.842786  0.832408  0.098254  0.202715
# 2  0.989672  0.582800  0.771130  0.602875  0.807779
# 3  0.574940  0.606356  0.815500  0.816024  0.567238
# 4  0.927618  0.913741  0.679182  0.072604  0.962765
# 5  0.452965  0.872883  0.325624  0.225292  0.417663

# %%
df2.plot.bar()
# Out:
# <AxesSubplot:>

# %%
df2.plot.bar(stacked=True)
# Out:
# <AxesSubplot:>

# %%
df2.plot.scatter(x='a',y='b')
# Out:
# <AxesSubplot:xlabel='a', ylabel='b'>

# %%
df2.plot.box()
# Out:
# <AxesSubplot:>

# %%
df = pd.DataFrame(np.random.randn(1000,2),columns=['a','b'])

# %%
df.head()
# Out:
#           a         b
# 0  0.585202 -0.636961
# 1 -1.475547  0.110494
# 2 -2.333352 -1.097364
# 3 -2.602801 -1.477381
# 4  0.296403  0.395239

# %%
df.plot.hexbin(x='a',y='b',gridsize=25)
# Out:
# <AxesSubplot:xlabel='a', ylabel='b'>

# %%
df2['a'].plot.kde()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
df2.plot.kde()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
df2.plot.density()
# Out:
# <AxesSubplot:ylabel='Density'>
