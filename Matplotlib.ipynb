# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
import numpy as np

# %%
x=np.linspace(0,5,11)

# %%
y=x**2

# %%
x
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
y
# Out:
# array([ 0.  ,  0.25,  1.  ,  2.25,  4.  ,  6.25,  9.  , 12.25, 16.  ,
#        20.25, 25.  ])

# %%
plt.plot(x,y,'r')

# %%
plt.plot(x,y,'r')
plt.xlabel('x axis')
plt.ylabel('y axis')
plt.title('title')
plt.show()

# %%
fig = plt.figure()

axes1 = fig.add_axes([0.1,0.1,0.8,0.8])
axes2 = fig.add_axes([0.2,0.5,0.4,0.3])

axes1.plot(x,y,'b')
axes1.set_xlabel('x-axis')
axes1.set_ylabel('y-axis')
axes1.set_title('title_axes1')

axes2.plot(x,y,'g')
axes2.set_xlabel('x-axis')
axes2.set_ylabel('y-axis')
axes2.set_title('title_axes2')
# Out:
# Text(0.5, 1.0, 'title_axes2')

# %%
fig,axes=plt.subplots()

axes.plot(x,y,'r')
axes.set_xlabel('x-axis')
axes.set_ylabel('y-axis')
axes.set_title('title_axes')
# Out:
# Text(0.5, 1.0, 'title_axes')

# %%
fig,axes=plt.subplots(nrows=1 , ncols=2)

# %%
axes
# Out:
# array([<AxesSubplot:>, <AxesSubplot:>], dtype=object)

# %%
for ax in axes:
    ax.plot(x,y,'r')
    ax.set_xlabel('x-axis')
    ax.set_ylabel('y-axis')
    ax.set_title('title_axes')
fig

# %%
fig,axes=plt.subplots(nrows=1 , ncols=2)
for ax in axes:
    ax.plot(x,y,'r')
    ax.set_xlabel('x-axis')
    ax.set_ylabel('y-axis')
    ax.set_title('title_axes')
fig
plt.tight_layout()

# %% [markdown]
# Y-axis not overlap as above garph

# %%
fig = plt.figure(figsize=(8,4),dpi=100)

# %%
fig,axes=plt.subplots(figsize=(12,3))

axes.plot(x,y,'r')
axes.set_xlabel('x-axis')
axes.set_ylabel('y-axis')
axes.set_title('title_axes')
# Out:
# Text(0.5, 1.0, 'title_axes')

# %%
fig.savefig('filename.png')

# %%
ax.set_title('title')
# Out:
# Text(0.5, 1.0, 'title')

# %%
ax.set_xlabel('x')
ax.set_ylabel('y')
# Out:
# Text(227.80000000000004, 0.5, 'y')

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.plot(x,x**2, label ='x**2')
ax.plot(x,x**3, label= 'x**3')
ax.legend()

# %%
# colors

# %%
fig,ax = plt.subplots()
ax.plot(x,x**2,'b.-')
ax.plot(x,x**3,'g*-')

# %%
fig,ax = plt.subplots()
ax.plot(x,x+1,color='blue',alpha=0.5)
ax.plot(x,x+2,color='green')
ax.plot(x,x+3,color='red')

# %%
fig,ax=plt.subplots(figsize=(12,6))

ax.plot(x,x+1,color='red',linewidth=0.25)
ax.plot(x,x+2,color='red',linewidth=0.5)
ax.plot(x,x+3,color='red',linewidth=1)
ax.plot(x,x+4,color='red',linewidth=2)

ax.plot(x,x+5,color='green',lw=3,ls='-')
ax.plot(x,x+6,color='green',lw=3,ls='-.')
ax.plot(x,x+7,color='green',lw=3,ls=':')

ax.plot(x,x+9,color='black',lw=3,ls='-',marker='o',markersize=10,markerfacecolor='red')

# %%
# axis appaearance

# %%
fig, axes = plt.subplots(1,3,figsize=(12,4))
axes[0].plot(x,x**2,x,x**3)
axes[0].set_title('axes ranges')

axes[1].plot(x,x**2,x,x**3)
axes[1].axis('tight')
axes[1].set_title('tight axes')

axes[2].plot(x,x**2,x,x**3)
axes[2].set_ylim([0,60])
axes[2].set_xlim([2,5])
axes[2].set_title('custom axes')
# Out:
# Text(0.5, 1.0, 'custom axes')

# %%
# special plot

# %%
plt.scatter(x,y)

# %%
from random import sample
data = sample(range(1,1000),100)

plt.hist(data)
# Out:
# (array([11., 10.,  7.,  8.,  9.,  9., 17., 10., 12.,  7.]),
#  array([ 10. , 106.6, 203.2, 299.8, 396.4, 493. , 589.6, 686.2, 782.8,
#         879.4, 976. ]),
#  <BarContainer object of 10 artists>)

# %%
data=[np.random.normal(0,std,100) for std in range(1,4)]
plt.boxplot(data, vert=True,patch_artist=True)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2d9702c2430>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2d9702c29d0>,
# ...
#  'boxes': [<matplotlib.patches.PathPatch at 0x2d9702c2070>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x2d9702c2f70>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x2d9702cd280>,
# ...
#  'means': []}
